# %% [markdown]
# # Linear Regression - using SciKit Learn

# %% [markdown]
# knowledge refresh on Linear regression 2/2

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(20.0,10.0)

#reading Data
data = pd.read_csv('headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X=data['Head Size(cm^3)']
Y=data['Brain Weight(grams)']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

m=len(X)
X=X.values.reshape((m,1))
reg=LinearRegression()
reg = reg.fit(X,Y)
Y_pred =reg.predict(X)
r2_score = reg.score(X,Y)
print (r2_score)
# Out:
# 0.639311719957

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams['figure.figsize']=(10.0,7.0)

font = {'family': 'sansserif',
        'color':  'darkgrey',
        'weight': 'normal',
        'size': 12,
        }

max_x = np.max(X)+100
min_x = np.min(X)-100

figure = plt.figure()

plt.plot(X,Y_pred,color='#225500',label='Regression Line')
plt.scatter(X,Y,c='#ef5400',label='All samples', alpha=0.7)

plt.title('Dynamic Linear Regression computation')

plt.xlim(min_x, max_x)
plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
